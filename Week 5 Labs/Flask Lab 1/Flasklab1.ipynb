# %%
# Import necessary libraries
from flask import Flask

# Initialize the Flask application
app = Flask(__name__)

# Define a route
@app.route('/')
def home():
    return "Hello, Flask in Jupyter Notebook!"

# Run the Flask app
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [19/Oct/2025 19:13:21] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Oct/2025 19:13:22] "GET /favicon.ico HTTP/1.1" 404 -

# %%
from flask import Flask

# Initialize Flask application
app = Flask(__name__)

# Define a simple route
@app.route('/')
def home():
    return "Hello, Flask in Jupyter!"

# Running the application in a notebook with custom host and port
if __name__ == '__main__':
    app.run(host='0.0.0.0', port=8080, debug=True, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8080
#  * Running on http://192.168.0.16:8080
# Press CTRL+C to quit
# 192.168.0.16 - - [18/Oct/2025 13:41:31] "GET / HTTP/1.1" 200 -
# 192.168.0.16 - - [18/Oct/2025 13:41:31] "GET /favicon.ico HTTP/1.1" 404 -

# %%
from flask import Flask
from threading import Thread

app = Flask(__name__)

@app.route('/')
def home():
    return "Flask running in the background in Jupyter Notebook!"

def run_flask():
    app.run(host='0.0.0.0', port=5000, debug=True, use_reloader=False)

# Start Flask app in a thread
Thread(target=run_flask).start()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.0.16:5000
# Press CTRL+C to quit

# %%
print ("Hello")
# Out:
# Hello
